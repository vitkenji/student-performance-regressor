# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('features.csv')

# %%
print(df.head())
# Out:
#    age  Pstatus  Medu  Fedu  Mjob  Fjob  guardian  traveltime  studytime  \
# 0   18        0     4     4     0     4         1           2          2
# 1   17        1     1     1     0     2         0           1          2
# 2   15        1     1     1     0     2         1           1          2
# 3   15        1     4     2     1     3         1           1          3
# 4   16        1     3     3     2     2         0           1          2
#
#    failures  ...  freetime  goout  Dalc  Walc  health  absences  target  \
# 0         0  ...         3      4     1     1       3         4      11
# 1         0  ...         3      3     1     1       3         2      11
# 2         0  ...         3      2     2     3       3         6      12
# 3         0  ...         2      2     1     1       5         0      14
# 4         0  ...         3      2     1     2       5         0      13
#
#    is_male  urban_address  big_family
# 0        0              1           1
# 1        0              1           1
# 2        0              1           0
# 3        0              1           1
# 4        0              1           1
#
# [5 rows x 29 columns]

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['Dalc'], df['target'], color='blue', label='Dados')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(x='romantic', y='target', data=df, inner='box')
plt.show()
